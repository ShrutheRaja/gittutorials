# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrutheRaja/gittutorials/blob/main/Thyroid_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed
# bogomips	: 4399.99
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13290480 kB
# MemFree:         8779412 kB
# MemAvailable:   12379032 kB
# Buffers:          331320 kB
# Cached:          3451292 kB
# SwapCached:            0 kB
# Active:           591068 kB
# Inactive:        3657752 kB
# Active(anon):       1068 kB
# Inactive(anon):   466464 kB
# Active(file):     590000 kB
# Inactive(file):  3191288 kB
# Unevictable:           4 kB
# Mlocked:               4 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              3192 kB
# Writeback:             0 kB
# AnonPages:        465792 kB
# Mapped:           270580 kB
# Shmem:              1320 kB
# KReclaimable:     118540 kB
# Slab:             154372 kB
# SReclaimable:     118540 kB
# SUnreclaim:        35832 kB
# KernelStack:        4380 kB
# PageTables:         8596 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645240 kB
# Committed_AS:    1981520 kB
# ...

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/thyroid_dataset.csv')

# %%
df
# Out:
#       29  F  f f.1 f.2 f.3 f.4 f.5 f.6  t  ... f.14  ?.1 f.15   ?.2 f.16 ?.3  \
# 0     29  F  f   f   f   f   f   f   f  f  ...    t  128    f     ?    f   ?
# 1     41  F  f   f   f   f   f   f   f  f  ...    f    ?    f     ?    f   ?
# 2     36  F  f   f   f   f   f   f   f  f  ...    f    ?    f     ?    f   ?
# 3     32  F  f   f   f   f   f   f   f  f  ...    f    ?    f     ?    f   ?
# 4     60  F  f   f   f   f   f   f   f  f  ...    f    ?    f     ?    f   ?
# ...   .. .. ..  ..  ..  ..  ..  ..  .. ..  ...  ...  ...  ...   ...  ...  ..
# 9166  56  M  f   f   f   f   f   f   f  f  ...    t   64    t  0.83    t  77
# 9167  22  M  f   f   f   f   f   f   f  f  ...    t   91    t  0.92    t  99
# 9168  69  M  f   f   f   f   f   f   f  f  ...    t  113    t  1.27    t  89
# 9169  47  F  f   f   f   f   f   f   f  f  ...    t   75    t  0.85    t  88
# 9170  31  M  f   f   f   f   f   f   f  t  ...    t   66    t  1.02    t  65
#
#      f.17 ?.4  other  -[840801013]
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of       29  F  f f.1 f.2 f.3 f.4 f.5 f.6  t  ... f.14  ?.1 f.15   ?.2 f.16 ?.3  \
# 0     29  F  f   f   f   f   f   f   f  f  ...    t  128    f     ?    f   ?
# 1     41  F  f   f   f   f   f   f   f  f  ...    f    ?    f     ?    f   ?
# 2     36  F  f   f   f   f   f   f   f  f  ...    f    ?    f     ?    f   ?
# 3     32  F  f   f   f   f   f   f   f  f  ...    f    ?    f     ?    f   ?
# 4     60  F  f   f   f   f   f   f   f  f  ...    f    ?    f     ?    f   ?
# ...   .. .. ..  ..  ..  ..  ..  ..  .. ..  ...  ...  ...  ...   ...  ...  ..
# 9166  56  M  f   f   f   f   f   f   f  f  ...    t   64    t  0.83    t  77
# 9167  22  M  f   f   f   f   f   f   f  f  ...    t   91    t  0.92    t  99
# 9168  69  M  f   f   f   f   f   f   f  f  ...    t  113    t  1.27    t  89
# 9169  47  F  f   f   f   f   f   f   f  f  ...    t   75    t  0.85    t  88
# 9170  31  M  f   f   f   f   f   f   f  t  ...    t   66    t  1.02    t  65
#
# ...

# %%
# prompt:

print(df.head(2))
# Out:
#    29  F  f f.1 f.2 f.3 f.4 f.5 f.6  t  ... f.14  ?.1 f.15 ?.2 f.16 ?.3 f.17  \
# 0  29  F  f   f   f   f   f   f   f  f  ...    t  128    f   ?    f   ?    f
# 1  41  F  f   f   f   f   f   f   f  f  ...    f    ?    f   ?    f   ?    t
#
#   ?.4  other  -[840801013]
# 0   ?  other  -[840801014]
# 1  11  other  -[840801042]
#
# [2 rows x 30 columns]

# %%
# !ls
# Out:
# sample_data  thyroid_dataset.csv
